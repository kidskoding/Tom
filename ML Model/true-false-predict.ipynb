# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import os
import random
from PIL import Image
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score
from sklearn.base import BaseEstimator

# %%
import easyocr
from pylab import rcParams
rcParams['figure.figsize'] = 8,16
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
img=cv2.imread('MAT004.jpg')
img_resize = cv2.resize(img,(1748, 2480))

#plt.imshow(img_resize)

img_test_id = img_resize[240:300,360:550]
img_test_text = reader.readtext(img_test_id)[0][1]
print(img_test_text)
plt.imshow(img_test_id)

img_student_id = img_resize[250:320,1040:1300]
#plt.imshow(img_student_id)
img_student_text = reader.readtext(img_student_id)[0][1]
print(img_student_text)
# Out:
# MATO04
# 123|

# %%
img_q1 = img_resize[550:630,500:1200]

img_q1_t = img_resize[550:630,550:900]
img_q1_f = img_resize[550:630,900:1200]

plt.imshow(img_q1_f)


#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)


#set a thresh
thresh = 100

#convert img to grey
img_grey_q1_t = cv2.cvtColor(img_q1_t,cv2.COLOR_BGR2GRAY)
img_grey_q1_f = cv2.cvtColor(img_q1_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_q1_t = cv2.threshold(img_grey_q1_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_q1_f = cv2.threshold(img_grey_q1_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_q1_t, hierarchy = cv2.findContours(thresh_img_q1_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q1_t = len(contours_q1_t)
print(ccount_q1_t)  
contours_q1_f, hierarchy = cv2.findContours(thresh_img_q1_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q1_f = len(contours_q1_f)
print(ccount_q1_f)  

if ccount_q1_t > ccount_q1_f:
    print("True")
else:
    print("False")
# Out:
# 8
# 19
# False

# %%
img_q2 = img_resize[680:750,550:1200]


img_q2_t = img_resize[680:750,550:900]
img_q2_f = img_resize[680:750,900:1200]
plt.imshow(img_q2_t)



#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)


#set a thresh
thresh = 100

#convert img to grey
img_grey_q2_t = cv2.cvtColor(img_q2_t,cv2.COLOR_BGR2GRAY)
img_grey_q2_f = cv2.cvtColor(img_q2_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_q2_t = cv2.threshold(img_grey_q2_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_q2_f = cv2.threshold(img_grey_q2_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_q2_t, hierarchy = cv2.findContours(thresh_img_q2_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q2_t = len(contours_q2_t)
print(ccount_q2_t)  
contours_q2_f, hierarchy = cv2.findContours(thresh_img_q2_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q2_f = len(contours_q2_f)
print(ccount_q2_f)  

if ccount_q2_t > ccount_q2_f:
    print("True")
else:
    print("False")
# Out:
# 15
# 8
# True

# %%
img_q3 = img_resize[800:950,550:1200]

img_q3_t = img_resize[800:950,550:900]
img_q3_f = img_resize[800:950,900:1200]
plt.imshow(img_q3_t)

#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)


#set a thresh
thresh = 100

#convert img to grey
img_grey_q3_t = cv2.cvtColor(img_q3_t,cv2.COLOR_BGR2GRAY)
img_grey_q3_f = cv2.cvtColor(img_q3_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_q3_t = cv2.threshold(img_grey_q3_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_q3_f = cv2.threshold(img_grey_q3_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_q3_t, hierarchy = cv2.findContours(thresh_img_q3_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q3_t = len(contours_q3_t)
print(ccount_q3_t)  
contours_q3_f, hierarchy = cv2.findContours(thresh_img_q3_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q3_f = len(contours_q3_f)
print(ccount_q3_f)  

if ccount_q3_t > ccount_q3_f:
    print("True")
else:
    print("False")
# Out:
# 14
# 9
# True

# %%
img_q4 = img_resize[1070:1160,550:1200]

img_q4_t = img_resize[1070:1160,550:900]
img_q4_f = img_resize[1070:1160,900:1200]
plt.imshow(img_q4_f)

#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)

#set a thresh
thresh = 100

#convert img to grey
img_grey_q4_t = cv2.cvtColor(img_q4_t,cv2.COLOR_BGR2GRAY)
img_grey_q4_f = cv2.cvtColor(img_q4_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_q4_t = cv2.threshold(img_grey_q4_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_q4_f = cv2.threshold(img_grey_q4_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_q4_t, hierarchy = cv2.findContours(thresh_img_q4_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q4_t = len(contours_q4_t)
print(ccount_q4_t)  
contours_q4_f, hierarchy = cv2.findContours(thresh_img_q4_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q4_f = len(contours_q4_f)
print(ccount_q4_f)  

if ccount_q4_t > ccount_q4_f:
    print("True")
else:
    print("False")
# Out:
# 11
# 9
# True

# %%
img_q5 = img_resize[1200:1300,550:1200]

img_q5_t = img_resize[1180:1330,550:900]
img_q5_f = img_resize[1210:1330,900:1200]
plt.imshow(img_q5_f)

#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)

#set a thresh
thresh = 100

#convert img to grey
img_grey_q5_t = cv2.cvtColor(img_q5_t,cv2.COLOR_BGR2GRAY)
img_grey_q5_f = cv2.cvtColor(img_q5_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_q5_t = cv2.threshold(img_grey_q5_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_q5_f = cv2.threshold(img_grey_q5_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_q5_t, hierarchy = cv2.findContours(thresh_img_q5_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q5_t = len(contours_q5_t)
print(ccount_q5_t)  
contours_q5_f, hierarchy = cv2.findContours(thresh_img_q5_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_q5_f = len(contours_q5_f)
print(ccount_q5_f)  

if ccount_q5_t > ccount_q5_f:
    print("True")
else:
    print("False")
# Out:
# 11
# 10
# True

# %%
IMG_WIDTH = 200
IMG_HEIGHT = 100

# %%
img_orig=cv2.imread('TF00.jpg')
#img_resize = cv2.resize(img1,(IMG_WIDTH,IMG_HEIGHT))

img_t = img_orig[0:100,0:100]
img_f = img_orig[0:100,100:200]

#img_text = reader.readtext(img_f)
#print(img_text)
#plt.imshow(img_f)

#set a thresh
thresh = 100

#convert img to grey
img_grey_t = cv2.cvtColor(img_t,cv2.COLOR_BGR2GRAY)
img_grey_f = cv2.cvtColor(img_f,cv2.COLOR_BGR2GRAY)

#get threshold image
ret, thresh_img_t = cv2.threshold(img_grey_t, thresh, 255, cv2.THRESH_BINARY)
ret, thresh_img_f = cv2.threshold(img_grey_f, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours_t, hierarchy = cv2.findContours(thresh_img_t, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_orig_t = len(contours_t)
print(ccount_orig_t)  # 11
contours_f, hierarchy = cv2.findContours(thresh_img_f, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
ccount_orig_f = len(contours_f)
print(ccount_orig_f)  # 16
# Out:
# 11
# 16

# %%
img = cv2.imread('TF01T.jpg', cv2.IMREAD_UNCHANGED)

#convert img to grey
img_grey = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#set a thresh
thresh = 100
#get threshold image
ret,thresh_img = cv2.threshold(img_grey, thresh, 255, cv2.THRESH_BINARY)
#find contours
contours, hierarchy = cv2.findContours(thresh_img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

#create an empty image for contours
img_contours = np.zeros(img.shape)

#print(closed_contours)

# draw the contours on the empty image
#print(img_contours)
cv2.drawContours(img_contours, contours, -1, (0,255,0), -1)
#cv2.RETR_TREE
print(len(contours))
#save image
cv2.imwrite('TF01T-new.jpg',img_contours)
# Out:
# 58
# True

# %%
img2=cv2.imread('TF02F-new.jpg')
plt.imshow(img2)

# %%
metadata = pd.read_csv('meta-tf.csv')

X = []
X_g = []
y = []

for i in tqdm(range(len(metadata))):
  image_meta = metadata.iloc[i]
  path = image_meta['ImageId'] + '.jpg'
  img = cv2.imread(path,cv2.IMREAD_COLOR)
  img = cv2.resize(img,(IMG_WIDTH,IMG_HEIGHT))
  
  img_g = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  X_g.append(img_g)

  X.append(img)
  y.append(image_meta['category'])

X_g = np.array(X_g)
X = np.array(X)
y = np.array(y)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3,random_state=1)

# %%
X_train.shape[3]
# Out:
# 3

# %%
number_of_train = X_train.shape[0]
number_of_test = X_test.shape[0]

# %%
X_train_flatten = X_train.reshape(number_of_train,X_train.shape[1]*X_train.shape[2]*X_train.shape[3])
X_test_flatten = X_test .reshape(number_of_test,X_test.shape[1]*X_test.shape[2]*X_test.shape[3])
print("X train flatten",X_train_flatten.shape)
print("X test flatten",X_test_flatten.shape)
# Out:
# X train flatten (7, 22500)
# X test flatten (3, 22500)

# %%
x_train = X_train_flatten.T
x_test = X_test_flatten.T
y_test = y_test.T
y_train = y_train.T
print("x train: ",x_train.shape)
print("x test: ",x_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (22500, 7)
# x test:  (22500, 3)
# y train:  (7,)
# y test:  (3,)

# %%
model = LogisticRegression(solver="liblinear", random_state=1)
model.fit(x_train,y_train)
y_predict = model.predict(x_test)

model_score = model.score(x_test, y_test)
print(model_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11236\1538975311.py in <module>
#       1 model = LogisticRegression(solver="liblinear", random_state=1)
# ----> 2 model.fit(x_train,y_train)
#       3 y_predict = model.predict(x_test)
#       4
#       5 model_score = model.score(x_test, y_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1506             _dtype = [np.float64, np.float32]
#    1507
# -> 1508         X, y = self._validate_data(
#    1509             X,
#    1510             y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
# --> 981     check_consistent_length(X, y)
#     982
#     983     return X, y
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [22500, 7]
